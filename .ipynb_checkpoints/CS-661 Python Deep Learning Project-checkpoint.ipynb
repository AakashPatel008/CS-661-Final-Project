# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime
import os
import cv2

import tensorflow as tf
from tensorflow.keras.optimizers import Adam, RMSprop, SGD

from keras import regularizers
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from keras.callbacks import ModelCheckpoint, CSVLogger, TensorBoard, EarlyStopping, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator, load_img

from sklearn.metrics import classification_report, confusion_matrix

# %%
train_dir = 'C:/Users/kunal/OneDrive/Desktop/Expression Dataset/train/'
test_dir = 'C:/Users/kunal/OneDrive/Desktop/Expression Dataset/test/'

row = 48
col = 48
classes = len(os.listdir('C:/Users/kunal/OneDrive/Desktop/Expression Dataset/train/'))

# %%
print("Train Set :")

train_count = []
for folder in os.listdir(train_dir) :
    print(folder, "folder contains\t\t", len(os.listdir(train_dir+folder)), "image")
    train_count.append(len(os.listdir(train_dir+folder)))
    
print()

test_count = []
print("Test Set :")
for folder in os.listdir(test_dir) :
    print(folder, "folder contains\t\t", len(os.listdir(test_dir+folder)), "images")
    test_count.append(len(os.listdir(test_dir+folder)))
# Out:
# Train Set :
# angry folder contains		 3995 image
# disgust folder contains		 436 image
# fear folder contains		 4097 image
# happy folder contains		 7215 image
# neutral folder contains		 4965 image
# sad folder contains		 4830 image
# surprise folder contains		 3171 image
#
# Test Set :
# angry folder contains		 958 images
# disgust folder contains		 111 images
# fear folder contains		 1024 images
# happy folder contains		 1774 images
# neutral folder contains		 1233 images
# sad folder contains		 1247 images
# surprise folder contains		 831 images

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.3,
                                   horizontal_flip=True)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
class_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprised']

img, label = next(training_set)

# %%
import random



i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
model = tf.keras.models.Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding='same', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, kernel_size=(3, 3),padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(256, kernel_size=(3, 3),padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  batch_normalization_1 (Bat  (None, 12, 12, 256)       1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 256)         0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 5111815 (19.50 MB)
# Trainable params: 5111175 (19.50 MB)
# Non-trainable params: 640 (2.50 KB)
# _________________________________________________________________
# None

# %%
chk_path = 'ferNet.h5'
log_dir = "checkpoint/logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             moniter='val_accuracy')

earlystop = EarlyStopping(monitor='val_accuracy', 
                          min_delta=0, 
                          patience=3, 
                          verbose=1, 
                          restore_best_weights=True)
                        
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                              factor=0.2, 
                              patience=6, 
                              verbose=1, 
                              min_delta=0.0001)


tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
csv_logger = CSVLogger('training.log')

callbacks = [checkpoint, reduce_lr, csv_logger]

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = test_set.n // test_set.batch_size

hist = model.fit(x=training_set,
                  validation_data=test_set,
                  epochs=25,
                  callbacks=callbacks,
                  steps_per_epoch=steps_per_epoch,
                  validation_steps=validation_steps)
# Out:
# Epoch 1/25
# 448/448 [==============================] - ETA: 0s - loss: 3.1718 - accuracy: 0.2714
# Epoch 1: val_loss improved from inf to 6.77880, saving model to ferNet.h5
# C:\Users\kunal\anaconda3\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 448/448 [==============================] - 620s 1s/step - loss: 3.1718 - accuracy: 0.2714 - val_loss: 6.7788 - val_accuracy: 0.1860 - lr: 0.0010
# Epoch 2/25
# 448/448 [==============================] - ETA: 0s - loss: 1.8094 - accuracy: 0.3391
# Epoch 2: val_loss improved from 6.77880 to 1.72228, saving model to ferNet.h5
# 448/448 [==============================] - 436s 973ms/step - loss: 1.8094 - accuracy: 0.3391 - val_loss: 1.7223 - val_accuracy: 0.3838 - lr: 0.0010
# Epoch 3/25
# 448/448 [==============================] - ETA: 0s - loss: 1.7010 - accuracy: 0.3830
# Epoch 3: val_loss improved from 1.72228 to 1.59260, saving model to ferNet.h5
# 448/448 [==============================] - 621s 1s/step - loss: 1.7010 - accuracy: 0.3830 - val_loss: 1.5926 - val_accuracy: 0.4378 - lr: 0.0010
# Epoch 4/25
# 448/448 [==============================] - ETA: 0s - loss: 1.6536 - accuracy: 0.4139
# Epoch 4: val_loss did not improve from 1.59260
# 448/448 [==============================] - 452s 1s/step - loss: 1.6536 - accuracy: 0.4139 - val_loss: 1.7256 - val_accuracy: 0.3917 - lr: 0.0010
# Epoch 5/25
# 448/448 [==============================] - ETA: 0s - loss: 1.6096 - accuracy: 0.4337
# Epoch 5: val_loss improved from 1.59260 to 1.57410, saving model to ferNet.h5
# 448/448 [==============================] - 426s 951ms/step - loss: 1.6096 - accuracy: 0.4337 - val_loss: 1.5741 - val_accuracy: 0.4605 - lr: 0.0010
# Epoch 6/25
# 448/448 [==============================] - ETA: 0s - loss: 1.5906 - accuracy: 0.4444
# Epoch 6: val_loss improved from 1.57410 to 1.49256, saving model to ferNet.h5
# 448/448 [==============================] - 428s 955ms/step - loss: 1.5906 - accuracy: 0.4444 - val_loss: 1.4926 - val_accuracy: 0.4798 - lr: 0.0010
# Epoch 7/25
# 448/448 [==============================] - ETA: 0s - loss: 1.5616 - accuracy: 0.4533
# Epoch 7: val_loss improved from 1.49256 to 1.43217, saving model to ferNet.h5
# 448/448 [==============================] - 429s 956ms/step - loss: 1.5616 - accuracy: 0.4533 - val_loss: 1.4322 - val_accuracy: 0.4993 - lr: 0.0010
# Epoch 8/25
# 448/448 [==============================] - ETA: 0s - loss: 1.5407 - accuracy: 0.4603
# Epoch 8: val_loss improved from 1.43217 to 1.42212, saving model to ferNet.h5
# 448/448 [==============================] - 428s 955ms/step - loss: 1.5407 - accuracy: 0.4603 - val_loss: 1.4221 - val_accuracy: 0.5039 - lr: 0.0010
# Epoch 9/25
# 448/448 [==============================] - ETA: 0s - loss: 1.5204 - accuracy: 0.4667
# Epoch 9: val_loss did not improve from 1.42212
# 448/448 [==============================] - 427s 954ms/step - loss: 1.5204 - accuracy: 0.4667 - val_loss: 1.5885 - val_accuracy: 0.4489 - lr: 0.0010
# Epoch 10/25
# 448/448 [==============================] - ETA: 0s - loss: 1.5021 - accuracy: 0.4774
# Epoch 10: val_loss improved from 1.42212 to 1.41289, saving model to ferNet.h5
# 448/448 [==============================] - 427s 954ms/step - loss: 1.5021 - accuracy: 0.4774 - val_loss: 1.4129 - val_accuracy: 0.5038 - lr: 0.0010
# Epoch 11/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4914 - accuracy: 0.4839
# Epoch 11: val_loss did not improve from 1.41289
# 448/448 [==============================] - 432s 964ms/step - loss: 1.4914 - accuracy: 0.4839 - val_loss: 1.4170 - val_accuracy: 0.5077 - lr: 0.0010
# Epoch 12/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4840 - accuracy: 0.4848
# Epoch 12: val_loss did not improve from 1.41289
# 448/448 [==============================] - 436s 973ms/step - loss: 1.4840 - accuracy: 0.4848 - val_loss: 1.4575 - val_accuracy: 0.4908 - lr: 0.0010
# Epoch 13/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4738 - accuracy: 0.4862
# Epoch 13: val_loss improved from 1.41289 to 1.36871, saving model to ferNet.h5
# 448/448 [==============================] - 427s 953ms/step - loss: 1.4738 - accuracy: 0.4862 - val_loss: 1.3687 - val_accuracy: 0.5306 - lr: 0.0010
# Epoch 14/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4575 - accuracy: 0.4971
# Epoch 14: val_loss did not improve from 1.36871
# 448/448 [==============================] - 428s 954ms/step - loss: 1.4575 - accuracy: 0.4971 - val_loss: 1.4066 - val_accuracy: 0.5226 - lr: 0.0010
# Epoch 15/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4500 - accuracy: 0.4942
# Epoch 15: val_loss improved from 1.36871 to 1.30806, saving model to ferNet.h5
# 448/448 [==============================] - 429s 958ms/step - loss: 1.4500 - accuracy: 0.4942 - val_loss: 1.3081 - val_accuracy: 0.5554 - lr: 0.0010
# Epoch 16/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4346 - accuracy: 0.5011
# Epoch 16: val_loss did not improve from 1.30806
# 448/448 [==============================] - 429s 957ms/step - loss: 1.4346 - accuracy: 0.5011 - val_loss: 1.3273 - val_accuracy: 0.5412 - lr: 0.0010
# Epoch 17/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4306 - accuracy: 0.4966
# Epoch 17: val_loss did not improve from 1.30806
# 448/448 [==============================] - 429s 958ms/step - loss: 1.4306 - accuracy: 0.4966 - val_loss: 1.3656 - val_accuracy: 0.5259 - lr: 0.0010
# Epoch 18/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4213 - accuracy: 0.5079
# Epoch 18: val_loss improved from 1.30806 to 1.29483, saving model to ferNet.h5
# 448/448 [==============================] - 429s 957ms/step - loss: 1.4213 - accuracy: 0.5079 - val_loss: 1.2948 - val_accuracy: 0.5552 - lr: 0.0010
# Epoch 19/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4143 - accuracy: 0.5102
# Epoch 19: val_loss improved from 1.29483 to 1.28249, saving model to ferNet.h5
# 448/448 [==============================] - 429s 957ms/step - loss: 1.4143 - accuracy: 0.5102 - val_loss: 1.2825 - val_accuracy: 0.5646 - lr: 0.0010
# Epoch 20/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4100 - accuracy: 0.5096
# Epoch 20: val_loss did not improve from 1.28249
# 448/448 [==============================] - 428s 956ms/step - loss: 1.4100 - accuracy: 0.5096 - val_loss: 1.3802 - val_accuracy: 0.5391 - lr: 0.0010
# Epoch 21/25
# 448/448 [==============================] - ETA: 0s - loss: 1.4028 - accuracy: 0.5131
# Epoch 21: val_loss improved from 1.28249 to 1.27858, saving model to ferNet.h5
# 448/448 [==============================] - 427s 954ms/step - loss: 1.4028 - accuracy: 0.5131 - val_loss: 1.2786 - val_accuracy: 0.5589 - lr: 0.0010
# Epoch 22/25
# 448/448 [==============================] - ETA: 0s - loss: 1.3975 - accuracy: 0.5169
# Epoch 22: val_loss did not improve from 1.27858
# 448/448 [==============================] - 426s 952ms/step - loss: 1.3975 - accuracy: 0.5169 - val_loss: 1.3509 - val_accuracy: 0.5352 - lr: 0.0010
# Epoch 23/25
# 448/448 [==============================] - ETA: 0s - loss: 1.3947 - accuracy: 0.5182
# Epoch 23: val_loss did not improve from 1.27858
# 448/448 [==============================] - 429s 958ms/step - loss: 1.3947 - accuracy: 0.5182 - val_loss: 1.3106 - val_accuracy: 0.5575 - lr: 0.0010
# Epoch 24/25
# 448/448 [==============================] - ETA: 0s - loss: 1.3914 - accuracy: 0.5234
# Epoch 24: val_loss did not improve from 1.27858
# 448/448 [==============================] - 428s 954ms/step - loss: 1.3914 - accuracy: 0.5234 - val_loss: 1.2864 - val_accuracy: 0.5624 - lr: 0.0010
# Epoch 25/25
# 448/448 [==============================] - ETA: 0s - loss: 1.3814 - accuracy: 0.5234
# Epoch 25: val_loss did not improve from 1.27858
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 448/448 [==============================] - 502s 1s/step - loss: 1.3814 - accuracy: 0.5234 - val_loss: 1.3300 - val_accuracy: 0.5465 - lr: 0.0010

# %%
model.save("model_trained.h5")

# %%
loss= hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc=hist.history['accuracy']
val_acc=hist.history['val_accuracy']
plt.plot(epochs, val_acc, 'y', label='Validation acc')
plt.plot(epochs, acc, 'r', label="Training acc")
plt.title('Training and validation accuracy')
#plt.xlable('Epochs')
#plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import os
import numpy as np
import cv2
from keras.models import load_model
from PIL import Image

home_folder = 'C:/Users/kunal/OneDrive/Desktop/Expression Dataset'
test_folder = os.path.join(home_folder, 'test')
train_folder = os.path.join(home_folder, 'train')

def load_images_from_folder(folder_path):
    images = []
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".JPG"):
            img = Image.open(os.path.join(folder_path, filename))
            if img is not None:
                images.append(img)
    return images

test_images = load_images_from_folder(test_folder)
train_images = load_images_from_folder(train_folder)

test_data = np.array([np.array(img) for img in test_images])
train_data = np.array([np.array(img) for img in train_images])

# Loading trained model
my_model = load_model('model_trained.h5', compile=False)

# Define the emotion labels
class_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprised']

# Initialize the camera
cap = cv2.VideoCapture(0)  
frame_count = 0  # Counter for frames
detected_emotion = None  

while True:
    # Capture frame-by-frame
    ret, frame = cap.read()

    if not ret:
        print("Failed to grab frame.")
        break

    # Preprocess the frame 
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    for (x, y, w, h) in faces:
        face_roi = gray[y:y + h, x:x + w]
        face_img = cv2.resize(face_roi, (48, 48))
        face_img = face_img / 255.0  # Normalize

        # Make predictions using your model
        predictions = my_model.predict(np.array([face_img.reshape(48, 48, 1)]))
        detected_emotion = class_labels[np.argmax(predictions)]

        # Draw a rectangle around the detected face and display the emotion
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        cv2.putText(frame, detected_emotion, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    cv2.imshow("webcam", frame)
    
    if frame_count == 15:  # Close the webcam after 1 seconds (assuming 25 frames per second)
        break

    frame_count += 1
    cv2.waitKey(1)

# Release the camera
cap.release()
cv2.destroyAllWindows()

# Access the detected emotion after the webcam closes
print("Detected Emotion:", detected_emotion)


import pandas as pd
mood_music=pd.read_csv(r"C:\Users\kunal\Downloads\archive (3)\data_moods.csv")

mood_music=mood_music[['name', 'artist', 'mood']]
mood_music.head()

#selecting music according to moods

if (detected_emotion=='Angry' or detected_emotion=='Disgust' or detected_emotion=='Fear'):
    filter1=mood_music['mood']=='Calm' #Filtering according to 'mood' column in dataset
    f1=mood_music.where(filter1)
    f1=f1.dropna() #dropping rows that are empty
    f2=f1.sample(n=5) #Displaying 5 songs
    f2.reset_index(inplace=True)
    f3=f2.drop(["mood"], axis=1)
    display(f3)
    
if (detected_emotion=='Happy' or detected_emotion=='Neutral'):
    filter1=mood_music['mood']=='Happy' #Filtering according to 'mood' column in dataset
    f1=mood_music.where(filter1)
    f1=f1.dropna() #dropping rows that are empty
    f2=f1.sample(n=5) #Displaying 5 songs
    f2.reset_index(inplace=True)
    f3=f2.drop(["mood"], axis=1)
    display(f3)
    
if (detected_emotion=='Sad'):
    filter1=mood_music['mood']=='Sad' #Filtering according to 'mood' column in dataset
    f1=mood_music.where(filter1)
    f1=f1.dropna() #dropping rows that are empty
    f2=f1.sample(n=5) #Displaying 5 songs
    f2.reset_index(inplace=True)
    f3=f2.drop(["mood"], axis=1)
    display(f3)
    
if (detected_emotion=='Surprised'):
    filter1=mood_music['mood']=='Energetic' #Filtering according to 'mood' column in dataset
    f1=mood_music.where(filter1)
    f1=f1.dropna() #dropping rows that are empty
    f2=f1.sample(n=5) #Displaying 5 songs
    f2.reset_index(inplace=True)
    f3=f2.drop(["mood"], axis=1)
    display(f3)
# Out:
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# Detected Emotion: Sad
#    index                      name           artist
# 0    598                    Unmade       Thom Yorke
# 1    370             Never My Love  Isobel Campbell
# 2    477  Should Have Known Better   Sufjan Stevens
# 3    453                 Riverside       Agnes Obel
# 4    258              I'm Your Man    Spiritualized
